# %%
from tools.custom_tools import query_table_tool

query_table_tool("select distinct CodA, CodP from Agricultor as A, Produto where CodP not in (select CodP from Entrega where CodA = A.CodA);")
# Out:
# Connecting to database...: <connection object at 0x12fdc1690; dsn: 'host='localhost' dbname='test' user='arturmagalhaes'', closed: 0>
# [(1001, 2001),
#  (1001, 2002),
#  (1001, 2004),
#  (1001, 2006),
#  (1001, 2007),
#  (1001, 2008),
#  (1001, 2009),
#  (1001, 2010),
#  (1001, 2011),
#  (1001, 2012),
#  (1001, 2013),
#  (1002, 2001),
#  (1002, 2004),
#  (1002, 2006),
#  (1002, 2008),
#  (1002, 2009),
#  (1002, 2010),
#  (1002, 2011),
#  (1002, 2012),
#  (1002, 2013),
#  (1003, 2001),
#  (1003, 2004),
#  (1003, 2005),
#  (1003, 2006),
#  (1003, 2007),
#  (1003, 2008),
#  (1003, 2009),
#  (1003, 2010),
#  (1003, 2011),
#  (1003, 2013),
#  (1004, 2001),
#  (1004, 2004),
#  (1004, 2006),
#  (1004, 2007),
#  (1004, 2009),
#  (1004, 2011),
#  (1004, 2012),
#  (1004, 2013),
#  (1005, 2003),
#  (1005, 2004),
#  (1005, 2005),
#  (1005, 2006),
#  (1005, 2007),
#  (1005, 2008),
#  (1005, 2009),
#  (1005, 2010),
#  (1005, 2012),
#  (1005, 2013),
#  (1006, 2001),
#  (1006, 2002),
# ...
