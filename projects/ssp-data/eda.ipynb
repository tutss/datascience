# %%
import pandas as pd

# %%
data = pd.read_csv('ssp-data-20250423_193748.csv')
data.head()
# Out:
#    ano_data_item  idOcorrenciaMensal  idDelito  idDistrito nomeDistrito  \
# 0           2010                   0        38           0        DP-Sé
# 1           2010                   0        41           0        DP-Sé
# 2           2010                   0        72           0        DP-Sé
# 3           2010                   0        73           0        DP-Sé
# 4           2010                   0        43           0        DP-Sé
#
#    ano_lista  janeiro  fevereiro  marco  abril  ...  setembro  outubro  \
# 0       2010        4          3      1      4  ...         1        0
# 1       2010        4          3      1      4  ...         1        0
# 2       2010        0          0      0      0  ...         0        0
# 3       2010        0          0      0      0  ...         0        0
# 4       2010        1          0      0      0  ...         2        1
#
#    novembro  dezembro  publicado  total  delito_idDelito  \
# ...

# %%
dp_se = data[data['nomeDistrito'] == 'DP-Sé']
dp_se_homicidio = dp_se[dp_se.delito_nome.str.contains('HOMICÍDIO DOLOSO')]

# %%
dp_se_homicidio
# Out:
#    ano_data_item  idOcorrenciaMensal  idDelito  idDistrito nomeDistrito  \
# 0           2010                   0        38           0        DP-Sé
# 1           2010                   0        41           0        DP-Sé
# 2           2010                   0        72           0        DP-Sé
# 3           2010                   0        73           0        DP-Sé
#
#    ano_lista  janeiro  fevereiro  marco  abril  ...  setembro  outubro  \
# 0       2010        4          3      1      4  ...         1        0
# 1       2010        4          3      1      4  ...         1        0
# 2       2010        0          0      0      0  ...         0        0
# 3       2010        0          0      0      0  ...         0        0
#
#    novembro  dezembro  publicado  total  delito_idDelito  \
# 0         0         2         12     24               38
# 1         0         2         12     24               41
# 2         0         0         12      0               72
# ...
