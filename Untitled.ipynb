# %%
import pandas as pd

# %%
data = pd.read_csv('data_/Estabelecimentos_202007.csv')
data.head()
# Out:
# /home/tuts/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (8,9,10,11,23,24,235,236) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       CNES  CODUFMUN   COD_CEP  CPF_CNPJ  PF_PJ  NIV_DEP        CNPJ_MAN  \
# 0   153281    120001  69945000         0      3        3  84306737000127
# 1   257184    120001  69945000         0      3        3  84306737000127
# 2   258555    120001  69945000         0      3        3  84306737000127
# 3  3006166    120001  69945000         0      3        3  84306737000127
# 4  3382745    120001  69945000         0      3        3  84306737000127
#
#    COD_IR REGSAUDE MICR_REG  ... mun_ALTITUDE mun_AREA  uf_SIGLA_UF  \
# 0     NaN      NaN      NaN  ...         25.0  1574.55           AC
# 1     NaN      NaN      NaN  ...         25.0  1574.55           AC
# ...

# %%
mid = int(len(data)*.5)
mid
# Out:
# 161028

# %%
f_half = data.iloc[:mid]
s_half = data.iloc[mid:]

# %%
data.shape
# Out:
# (322057, 247)

# %%
f_half.shape
# Out:
# (161028, 247)

# %%
s_half.shape
# Out:
# (161029, 247)

# %%
f_half.shape[0] + s_half.shape[0]
# Out:
# 322057

# %%
f_half.head()
# Out:
#       CNES  CODUFMUN   COD_CEP  CPF_CNPJ  PF_PJ  NIV_DEP        CNPJ_MAN  \
# 0   153281    120001  69945000         0      3        3  84306737000127
# 1   257184    120001  69945000         0      3        3  84306737000127
# 2   258555    120001  69945000         0      3        3  84306737000127
# 3  3006166    120001  69945000         0      3        3  84306737000127
# 4  3382745    120001  69945000         0      3        3  84306737000127
#
#    COD_IR REGSAUDE MICR_REG  ... mun_ALTITUDE mun_AREA  uf_SIGLA_UF  \
# 0     NaN      NaN      NaN  ...         25.0  1574.55           AC
# 1     NaN      NaN      NaN  ...         25.0  1574.55           AC
# 2     NaN      NaN      NaN  ...         25.0  1574.55           AC
# 3     NaN      NaN      NaN  ...         25.0  1574.55           AC
# 4     NaN      NaN      NaN  ...         25.0  1574.55           AC
#
#   uf_NOME_UF  ano_competen  mes_competen  def_competen      mun_coordenadas  \
# ...

# %%
s_half.head()
# Out:
#            CNES  CODUFMUN   COD_CEP        CPF_CNPJ  PF_PJ  NIV_DEP  CNPJ_MAN  \
# 161028  6673848    411370  86010180  12331813000143      3        1         0
# 161029  6673856    411370  86060000  12099584000183      3        1         0
# 161030  6682618    411370  86010630       502070919      1        1         0
# 161031  6682626    411370  86020150    420424000105      3        1         0
# 161032  6682634    411370  86061332  12490131000183      3        1         0
#
#         COD_IR REGSAUDE MICR_REG  ... mun_ALTITUDE  mun_AREA  uf_SIGLA_UF  \
# 161028     NaN       17      NaN  ...        585.0  1650.809           PR
# 161029     NaN       17      NaN  ...        585.0  1650.809           PR
# 161030     NaN       17      NaN  ...        585.0  1650.809           PR
# 161031     NaN       17      NaN  ...        585.0  1650.809           PR
# 161032     NaN       17      NaN  ...        585.0  1650.809           PR
#
# ...

# %%
mid1 = int(f_half.shape[0]*.5)
mid2 = int(s_half.shape[0]*.5)

split_1_1 = f_half.iloc[:mid1]
split_1_2 = f_half.iloc[mid1:]

split_2_1 = s_half.iloc[:mid2]
split_2_2 = s_half.iloc[mid2:]

# %%
split_1_1.head()
# Out:
#       CNES  CODUFMUN   COD_CEP  CPF_CNPJ  PF_PJ  NIV_DEP        CNPJ_MAN  \
# 0   153281    120001  69945000         0      3        3  84306737000127
# 1   257184    120001  69945000         0      3        3  84306737000127
# 2   258555    120001  69945000         0      3        3  84306737000127
# 3  3006166    120001  69945000         0      3        3  84306737000127
# 4  3382745    120001  69945000         0      3        3  84306737000127
#
#    COD_IR REGSAUDE MICR_REG  ... mun_ALTITUDE mun_AREA  uf_SIGLA_UF  \
# 0     NaN      NaN      NaN  ...         25.0  1574.55           AC
# 1     NaN      NaN      NaN  ...         25.0  1574.55           AC
# 2     NaN      NaN      NaN  ...         25.0  1574.55           AC
# 3     NaN      NaN      NaN  ...         25.0  1574.55           AC
# 4     NaN      NaN      NaN  ...         25.0  1574.55           AC
#
#   uf_NOME_UF  ano_competen  mes_competen  def_competen      mun_coordenadas  \
# ...

# %%
split_1_1.shape
# Out:
# (80514, 247)

# %%
split_1_2.shape
# Out:
# (80514, 247)

# %%
split_2_1.shape
# Out:
# (80514, 247)

# %%
split_2_2.shape
# Out:
# (80515, 247)

# %%
split_1_1.to_csv('data_/split_1_1.csv', index=False)
split_1_2.to_csv('data_/split_1_2.csv', index=False)
split_2_1.to_csv('data_/split_2_1.csv', index=False)
split_2_2.to_csv('data_/split_2_2.csv', index=False)
